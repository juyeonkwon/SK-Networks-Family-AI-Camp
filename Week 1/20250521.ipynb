# %%
print("Hello World!!")
# Out:
# Hello World!!

# %%
import requests 
url = "https://www.starbucks.co.kr/store/getStore.do?r=86N465IIB2"
payload = {"in_biz_cds": "0",
"in_scodes": "0",
"ins_lat": "37.4745",
"ins_lng": "126.8918",
"search_text": "",
"p_sido_cd": "01",
"p_gugun_cd": "",
"in_distance": "0",
"in_biz_cd": "",
"isError": "true",
"searchType": "C",
"set_date": "",
"all_store": "0",
"T03": "0",
"T01": "0",
"T27": "0",
"T12": "0",
"T09": "0",
"T30": "0",
"T05": "0",
"T22": "0",
"T21": "0",
"T36": "0",
"T43": "0",
"Z9999": "0",
"T64": "0",
"T66": "0",
"P02": "0",
"P10": "0",
"P50": "0",
"P20": "0",
"P60": "0",
"P30": "0",
"P70": "0",
"P40": "0",
"P80": "0",
"whcroad_yn": "0",
"P90": "0",
"P01": "0",
"new_bool": "0",
"iend": "1000",
"rndCod": "XW4W0LA4X8",}
r = requests.post(url, data=payload)
star = r.json()

# %%
dir(star)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
star.keys()
# Out:
# dict_keys(['list'])

# %%
for store in star['list']:
    if store['s_name'][-2:] == "DT":
        print(store['s_name'])
# Out:
# 강남세곡DT
# 방화DT
# 화곡DT
# 김포공항DT
# 신림DT
# 낙성대DT
# 구의DT
# 공릉DT
# 태릉입구역DT
# 도봉로DT
# 연희DT
# 북가좌DT
# 남부순환로방배DT
# 종암DT
# 송파나루역DT
# 송파방이DT
# 송파마천사거리DT
# 신정DT
# 신월IC DT
# 신월동DT
# 진관DT
# 강동구청DT
# 강동암사DT
# 구로오류DT

# %%
tmp = {} 
tmp['a'] = 10

# %%
tmp['a'] = 20

# %%
'a' in tmp
# Out:
# True

# %%
'gugun_name'

# %%
tmp = {}
for x in "abcdeaae":
    if x in tmp:
        # print(tmp[x])
        tmp[x] = tmp[x]+ 1
    else:
        tmp[x] = 1

# %%
gugun = {}
for store in star['list']:
    if store['gugun_name'] in gugun:
        #gugun[store['gugun_name']] = gugun[store['gugun_name']] + 1
        gugun[store['gugun_name']] += 1
    else:
        # 초기값 
        gugun[store['gugun_name']] = 1

# %%
lyrics = """따사로운 햇살 속에서
종소리가 울려 퍼지네
뺨을 매만지는 바람
한숨만은 깊어져만 가고
저 멀리서 핑 도는 눈물
이름을 붙여준 내일
포개어지는 미래 빛 라인
천진난만한 이런 기분도
신이 나서 날아갈 정도로 웃었던 날도
사랑스럽고 소중하게 키울 수 있도록
어렵고 힘들었던 시간을 넘어서
아주 많은 처음을 주었잖아
이어져 가서는 닿기를
천진난만한 이런 기분도
신이 나서 날아갈 정도로 웃었던 날도
사랑스럽고 소중하게 키울 수 있도록
어렵고 힘들었던 시간을 넘어서
아주 많은 처음을 주었잖아
이어져 가서는
천진난만한 이런 기분도
신이 나서 날아갈 정도로 웃었던 날도
사랑스럽고 소중하게 키울 수 있도록
어렵고 힘들었던 시간을 넘어서
아주 많은 처음을 주었잖아
이어져 가서는
이어져 가서는 닿기를"""

# %%
dir(lyrics)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
word_cnt = {}
for word in lyrics.split():
    if len(word) > 1:
        if word in word_cnt:
            word_cnt[word] += 1
        else:
            word_cnt[word] = 1

# %%
sorted(word_cnt.items(), key= lambda x : x[1], reverse=True)
# Out:
# [('이어져', 4),
#  ('가서는', 4),
#  ('천진난만한', 3),
#  ('이런', 3),
#  ('기분도', 3),
#  ('신이', 3),
#  ('나서', 3),
#  ('날아갈', 3),
#  ('정도로', 3),
#  ('웃었던', 3),
#  ('날도', 3),
#  ('사랑스럽고', 3),
#  ('소중하게', 3),
#  ('키울', 3),
#  ('있도록', 3),
#  ('어렵고', 3),
#  ('힘들었던', 3),
#  ('시간을', 3),
#  ('넘어서', 3),
#  ('아주', 3),
#  ('많은', 3),
#  ('처음을', 3),
#  ('주었잖아', 3),
#  ('닿기를', 2),
#  ('따사로운', 1),
#  ('햇살', 1),
#  ('속에서', 1),
#  ('종소리가', 1),
#  ('울려', 1),
#  ('퍼지네', 1),
#  ('뺨을', 1),
#  ('매만지는', 1),
#  ('바람', 1),
#  ('한숨만은', 1),
#  ('깊어져만', 1),
#  ('가고', 1),
#  ('멀리서', 1),
#  ('도는', 1),
#  ('눈물', 1),
#  ('이름을', 1),
#  ('붙여준', 1),
#  ('내일', 1),
#  ('포개어지는', 1),
#  ('미래', 1),
#  ('라인', 1)]

# %%
store
# Out:
# {'seq': 0,
#  'sido_cd': None,
#  'sido_nm': None,
#  'gugun_cd': None,
#  'gugun_nm': None,
#  'code_order': None,
#  'view_yn': None,
#  'store_num': None,
#  'sido': None,
#  'gugun': None,
#  'address': None,
#  'new_img_nm': None,
#  'p_pro_seq': 0,
#  'p_view_yn': None,
#  'p_sido_cd': '',
#  'p_gugun_cd': '',
#  'p_store_nm': None,
#  'p_theme_cd': None,
#  'p_wireless_yn': None,
#  'p_smoking_yn': None,
#  'p_book_yn': None,
#  'p_music_yn': None,
#  'p_terrace_yn': None,
#  'p_table_yn': None,
#  'p_takeout_yn': None,
#  'p_parking_yn': None,
#  'p_dollar_assent': None,
#  'p_card_recharge': None,
#  'p_subway_yn': None,
#  'stb_store_file_renew': None,
#  'stb_store_theme_renew': None,
#  'stb_store_time_renew': None,
#  'stb_store_lsm': None,
#  's_code': '1749',
#  's_name': '중화역',
#  'tel': '1522-3232',
#  'dlvry_call_cntr_phno': None,
#  'fax': '02-435-3802',
#  'sido_code': '01',
#  'sido_name': '서울',
#  'gugun_code': '0125',
#  'gugun_name': '중랑구',
# ...

# %%
text = '서울특별시 중랑구 중화동 306-68 중화동 HS빌딩 1,2층'

# %%
dir(text)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
text
# Out:
# '서울특별시 중랑구 중화동 306-68 중화동 HS빌딩 1,2층'

# %%
text.find("독산")
# Out:
# -1

# %%
for store in star['list']:
    #if store['addr'].find("가산") > -1:
    if '가산' in store['addr']:
        print(store['s_name'], store['addr'])
# Out:
# 가산에스케이 서울특별시 금천구 가산동 371-41, SK V1센터 1층
# 가산디지털단지역 서울특별시 금천구 가산동 50-3, 대륭포스트타워 6차 1층
# 가산디지털 서울특별시 금천구 가산동 371-28, 우림라이온스밸리 B동 1층
# 마리오아울렛 서울특별시 금천구 가산동 60-20 ㈜마리오 3관1층
# 가산브이타워 서울특별시 금천구 가산동 371-37, V-TOWER 1층
# 독산역 서울특별시 금천구 가산동 673, 107-2, 1층
# 가산퍼블릭 서울특별시 금천구 가산동 60-26, B동 F Park 1층
# 가산현대아울렛 서울특별시 금천구 가산동 60-8 현대시티아울렛 가산점, 1층 일부
# 가산케이에스 서울특별시 금천구 가산동 60-14, 가산KS타워 1층
# 가산어반워크 서울특별시 금천구 가산동 451-1

# %%
def get_starbucks(dong):
    for store in star['list']:
        #if store['addr'].find("가산") > -1:
        if dong in store['addr']:
            print(store['s_name'], store['addr'])

# %%
get_starbucks("청담")
# Out:
# 강남구청정문 서울특별시 강남구 청담동 44-12 대륭빌딩
# 청담영동대로 서울특별시 강남구 청담동 132-1 삼청빌딩
# 청담스타R 서울특별시 강남구 청담동 89-4
# 청담사거리 서울특별시 강남구 청담동 6-5 리츠타워
# 청담 서울특별시 강남구 청담동 52-1 인희빌딩 1층
# 압구정로데오역 서울특별시 강남구 청담동 84-3번지 삼원빌딩 1,2층
# 청담역 서울특별시 강남구 청담동 47-2
# 강남청담빌딩 서울특별시 강남구 청담동 41 청담빌딩

# %%
def multi(x, y, type_):
    if type_ == 'add':
        return (x + y)
    elif type_ == "multi":
        return (x * y)

# %%
result = multi(3,4, '')

# %%
result

# %% [markdown]
# BMI = 체중(kg) / (키(m) * 키(m))

# %%
def get_bmi(kg, cm ):
    return kg / (cm / 100)**2

# %%
get_bmi(70,180)
# Out:
# 21.604938271604937

# %%
(lambda kg, cm : kg / (cm / 100)**2)(70,180)
# Out:
# 21.604938271604937

# %%
import datetime
for day in range(100,1001, 100):
    print(datetime.datetime.today() + datetime.timedelta(days=day), end=" --> ")
    print((datetime.datetime.today() + datetime.timedelta(days=day)).weekday())
# Out:
# 2025-08-29 12:39:22.204182 --> 4
# 2025-12-07 12:39:22.204534 --> 6
# 2026-03-17 12:39:22.204534 --> 1
# 2026-06-25 12:39:22.204534 --> 3
# 2026-10-03 12:39:22.204534 --> 5
# 2027-01-11 12:39:22.204534 --> 0
# 2027-04-21 12:39:22.204534 --> 2
# 2027-07-30 12:39:22.204534 --> 4
# 2027-11-07 12:39:22.204534 --> 6
# 2028-02-15 12:39:22.204534 --> 1

# %%
store['open_dt']
# Out:
# '20201222'

# %%
datetime.datetime.strptime(store['open_dt'], "%Y%m%d").weekday()
# Out:
# 1

# %%
dict(zip(range(0,7), "월화수목금토일"))
# Out:
# {0: '월', 1: '화', 2: '수', 3: '목', 4: '금', 5: '토', 6: '일'}

# %%
days = {}
for store in star['list']:
    요일 = dict(zip(range(0,7), "월화수목금토일"))[datetime.datetime.strptime(store['open_dt'], "%Y%m%d").weekday()]
    if 요일 in days:
        days[요일] += 1
    else:
        days[요일] = 1

# %%
sorted(days.items(), key=lambda x : x[1], reverse=True)
# Out:
# [('목', 175), ('금', 159), ('화', 128), ('수', 126), ('월', 42), ('토', 6), ('일', 5)]

# %%
c:\window

c:/

# %%
# 절대경로 
#  c:\Users\play\workspace\a.txt 
# 상대경로 
# .\a.txt
import pickle 
#raw 
with open(r".\data\kbo_2024.pkl", "rb") as f:
    kbo = pickle.load(f)

# %%
kbo

# %%
pwd
# Out:
# 'c:\\Users\\play\\workspace'

# %%
import os 
os.getcwd()
# Out:
# 'c:\\Users\\play\\workspace'

# %%
"C:\Users\play\Downloads\kbo.csv"

# %%
with open("../Downloads/kbo.csv", 'r', encoding='utf-8') as f:
    data =f.read()

# %%
col = data.split("\n")[0].split(",")
kbo_list = []
for x in data.split("\n")[1:-1]:
    kbo_list.append(dict(zip(col, x.split(","))))

# %%
import re
p = re.compile("([0-9]{2,3})")

# %%
p.findall('180cm/71kg')
# Out:
# ['180', '71']

# %%
height, weight = '180cm/71kg'.split("/")
height = height.replace("cm", "")
weight = weight.replace("kg", "")

# %%
weight
# Out:
# '71'

# %%
kbo_list2 = [dict(zip(col, x.split(","))) for x in data.split("\n")[1:-1]]

# %%
for player in  kbo_list:
    height, weight = player['신장/체중'].split("/")
    height = height.replace("cm", "")
    weight = weight.replace("kg", "")
    try:
        player['weight'] = int(weight)
        player['height'] = int(height)
        player['bmi'] = round(get_bmi(player['weight'],player['height']),2)
    except:
        player['weight'] = ''
        player['height'] = ''
        player['bmi'] = 0

# %%
sorted({data['선수명'] : data['bmi'] for data in kbo_list}.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('김민우', 35.55),
#  ('김범석', 34.72),
#  ('박성웅', 34.4),
#  ('김기연', 33.46),
#  ('박상준', 32.82),
#  ('최형우', 32.72),
#  ('김승현', 32.41),
#  ('김도규', 32.01),
#  ('박진', 32.0),
#  ('진승현', 31.9),
#  ('이상준', 31.7),
#  ('황대인', 31.56),
#  ('나균안', 31.51),
#  ('이주형', 31.35),
#  ('장민재', 31.31),
#  ('류현진', 31.3),
#  ('박병호', 31.26),
#  ('손율기', 30.86),
#  ('후라도', 30.84),
#  ('최원태', 30.72),
#  ('이로운', 30.68),
#  ('노시환', 30.68),
#  ('안치홍', 30.61),
#  ('서의태', 30.56),
#  ('푸이그', 30.56),
#  ('이민우', 30.39),
#  ('로건', 30.35),
#  ('이명기', 30.35),
#  ('김태연', 30.3),
#  ('성동현', 30.23),
#  ('박지호', 30.22),
#  ('정민규', 30.16),
#  ('양지율', 30.09),
#  ('김지성', 30.06),
#  ('허관회', 30.02),
#  ('박성빈', 30.0),
#  ('배세종', 29.92),
#  ('김성진', 29.86),
#  ('나성범', 29.86),
#  ('신경민', 29.77),
#  ('김준태', 29.71),
#  ('디아즈', 29.71),
#  ('최재훈', 29.67),
#  ('한현희', 29.59),
#  ('김성재', 29.59),
#  ('오현석', 29.56),
#  ('김재형', 29.48),
#  ('주현상', 29.37),
#  ('문용익', 29.35),
#  ('박세진', 29.35),
#  ('오승환', 29.35),
#  ('김태호', 29.35),
#  ('오영수', 29.35),
# ...

# %%
for player in  kbo_list:
    player['초등'] = player['경력'].split("-")[0]

# %%
from collections import Counter

# %%
Counter([player['초등'] for player in kbo_list])
# Out:
# Counter({'가동초': 19,
#          '부산수영초': 15,
#          '양정초': 14,
#          '송정동초': 14,
#          '광주대성초': 14,
#          '광주수창초': 13,
#          '대구옥산초': 13,
#          '성동초': 11,
#          '광주서석초': 11,
#          '양덕초': 11,
#          '수원신곡초': 10,
#          '광주화정초': 10,
#          '본리초': 10,
#          '서울도곡초': 10,
#          '동막초': 9,
#          '학강초': 9,
#          '대전신흥초': 9,
#          '역삼초': 9,
#          '김해삼성초': 8,
#          '화곡초': 8,
#          '군산중앙초': 8,
#          '칠성초': 8,
#          '순천북초': 8,
#          '효제초': 8,
#          '서울청구초': 8,
#          '수유초': 7,
#          '서화초': 7,
#          '연현초': 7,
#          '서울학동초': 7,
#          '인천숭의초': 7,
#          '길동초': 7,
#          '고명초': 7,
#          '화순초': 7,
#          '인천서림초': 7,
#          '남도초': 6,
#          '서흥초': 6,
#          '온양온천초': 6,
#          '서울이수초': 6,
#          '신도초': 6,
#          '강남초': 6,
#          '도신초': 6,
#          '광주서림초': 6,
#          '중대초': 5,
#          '울산대현초': 5,
#          '인헌초': 5,
# ...

# %%
kbo_list[0]
# Out:
# {'선수명': '강민',
#  '등번호': 'No.100',
#  '생년월일': '2001년 04월 20일',
#  '포지션': '투수(우투우타)',
#  '신장/체중': '188cm/88kg',
#  '경력': '수유초-홍은중-서울고',
#  '입단 계약금': '8000만원',
#  '연봉': '3000만원',
#  '지명순위': '20 LG 2차 4라운드 33순위',
#  '입단년도': '',
#  'Team': 'LG 트윈스',
#  'aaa': 1,
#  '88': '88',
#  '188': '188',
#  'weight': 88,
#  'height': 188,
#  'bmi': 24.9,
#  '초등': '수유초'}

# %%
data2 = []
for x in kbo_list:
    data2.append( x['bmi'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[188], line 3
#       1 data2 = []
#       2 for x in kbo_list:
# ----> 3     data2.append( x['bmi'])
#
# KeyError: 'bmi'

# %%
x
# Out:
# {'선수명': '이정준',
#  '등번호': 'No.',
#  '생년월일': '1977년 06월 18일',
#  '포지션': '()',
#  '신장/체중': 'cm/kg',
#  '경력': '한서고-LG',
#  '입단 계약금': '',
#  '연봉': '',
#  '지명순위': '',
#  '입단년도': '',
#  'Team': 'LG 트윈스',
#  'aaa': 1,
#  '': '',
#  'weight': '',
#  'height': '',
#  '초등': '한서고'}

# %%
kbo_list[0]
# Out:
# {'선수명': '강민',
#  '등번호': 'No.100',
#  '생년월일': '2001년 04월 20일',
#  '포지션': '투수(우투우타)',
#  '신장/체중': '188cm/88kg',
#  '경력': '수유초-홍은중-서울고',
#  '입단 계약금': '8000만원',
#  '연봉': '3000만원',
#  '지명순위': '20 LG 2차 4라운드 33순위',
#  '입단년도': '',
#  'Team': 'LG 트윈스',
#  'aaa': 1,
#  '88': '88',
#  '188': '188',
#  'weight': 88,
#  'height': 188,
#  'bmi': 24.9,
#  '초등': '수유초'}
