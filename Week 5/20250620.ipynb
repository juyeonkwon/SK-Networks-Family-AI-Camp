# %%
import pandas as pd

# %%
pwd
# Out:
# '/home/play/workspace'

# %%
df = pd.read_csv("./data/speeddating.csv")

# %%
df.loc[:, (df.dtypes == 'object').values] = df.loc[:, (df.dtypes == 'object').values].map(lambda x: x.replace("b'", '').\
                                              replace("'", ""))

# %%
df.columns
# Out:
# Index(['has_null', 'wave', 'gender', 'age', 'age_o', 'd_age', 'd_d_age',
#        'race', 'race_o', 'samerace',
#        ...
#        'd_expected_num_interested_in_me', 'd_expected_num_matches', 'like',
#        'guess_prob_liked', 'd_like', 'd_guess_prob_liked', 'met', 'decision',
#        'decision_o', 'match'],
#       dtype='object', length=123)

# %%
df.columns.size
# Out:
# 123

# %%
df['match'].value_counts()
# Out:
# match
# 0    6998
# 1    1380
# Name: count, dtype: int64

# %%
df
# Out:
#      has_null  wave  gender   age  age_o  d_age d_d_age  \
# 0               1.0  female  21.0   27.0    6.0   [4-6]
# 1               1.0  female  21.0   22.0    1.0   [0-1]
# 2               1.0  female  21.0   22.0    1.0   [0-1]
# 3               1.0  female  21.0   23.0    2.0   [2-3]
# 4               1.0  female  21.0   24.0    3.0   [2-3]
# ...       ...   ...     ...   ...    ...    ...     ...
# 8373           21.0    male  25.0   26.0    1.0   [0-1]
# 8374           21.0    male  25.0   24.0    1.0   [0-1]
# 8375           21.0    male  25.0   29.0    4.0   [4-6]
# 8376           21.0    male  25.0   22.0    3.0   [2-3]
# 8377           21.0    male  25.0   22.0    3.0   [2-3]
#
#                                        race  \
# 0     Asian/Pacific Islander/Asian-American
# 1     Asian/Pacific Islander/Asian-American
# 2     Asian/Pacific Islander/Asian-American
# 3     Asian/Pacific Islander/Asian-American
# 4     Asian/Pacific Islander/Asian-American
# ...
